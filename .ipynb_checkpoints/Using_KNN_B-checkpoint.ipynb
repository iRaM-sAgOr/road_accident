# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from sklearn import preprocessing

# %%
csv = 'Crash_Data.csv'
my_df = pd.read_csv(csv)
my_df.head()
# Out:
#    Crash ID  Date  Day of Week  Time  Lane Count  Crash Type  \
# 0   9969918     4            1     2           3           3
# 1   9741036     4            1     1           3           1
# 2   9965952     4            1     1           3           1
# 3   9705367     4            1     1           2           3
# 4   9741034     4            2     1           3           3
#
#    Functional Class  Speed Limit  Environmental Conditions  Light Conditions  \
# 0                 2            4                         1                 4
# 1                 2            4                         1                 4
# 2                 2            4                         1                 3
# 3                 2            1                         2                 2
# 4                 2            4                         2                 4
#
#    ...  Total Vehicles Involved  Curve Related  Alcohol Involved  \
# 0  ...                        2              2                 2
# ...

# %%
my_df['Severity'].isnull().sum()
len(my_df['Severity'])
# Out:
# 8232

# %%
#Frequency distribution of classes"
train_outcome = pd.crosstab(index=my_df["Severity"],  # Make a crosstab
                              columns="count")      # Name the count column

train_outcome
# Out:
# col_0     count
# Severity
# 1            13
# 2           254
# 3          7965

# %%
X = my_df.iloc[:,1:-1].values
y = my_df.iloc[:,20].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# #Here we randomly split the datafram in order to the amount of data five per class
# from sklearn.model_selection import train_test_split
# def data_split(num):
#   total_train_df = pd.DataFrame()
#   total_test_df = pd.DataFrame()
#   one_six_train_df =pd.DataFrame()
#   for i in range(1,37):
#     temp_df =  my_df[my_df['Class']==i]
#     if (len(temp_df)>=6):
#       train_df, test_df = train_test_split(temp_df, train_size=6)
#       total_train_df = pd.concat([total_train_df,train_df])
#       total_test_df = pd.concat([total_test_df,test_df])
#       one_six_train_df = pd.concat([one_six_train_df,train_df[0:num]])

#   # print("This is from data_split",len(total_train_df),len(one_six_train_df))
#   return total_train_df,total_test_df,one_six_train_df

# %%
def split_x_y(total_train_df,total_test_df,one_six_train_df):
  # print("this is split_xy",one_six_train_df.shape)
  # print(type(total_train_df),total_train_df.shape)
  X_train = total_train_df.iloc[:,1:].values
  y_train = total_train_df.iloc[:,0].values
  X_test = total_test_df.iloc[:,1:].values
  y_test = total_test_df.iloc[:,0].values
  one_x = one_six_train_df.iloc[:,1:].values
  one_y = one_six_train_df.iloc[:,0].values
  # print("this is from split_X",len(X_train),type(X_train),len(y_train),type(y_train),one_x.shape,one_y.shape)
  return X_train,y_train,X_test,y_test,one_x,one_y

# %%
from sklearn.preprocessing import StandardScaler
def scaling_data(one_x,X_test):
  scaler_train = StandardScaler()
  scaler_train.fit(one_x)
  one_x = scaler_train.transform(one_x)
  # print(one_x)

  scaler_test = StandardScaler()
  scaler_test.fit(X_test)
  X_test = scaler_test.transform(X_test)
  # print(X_test)
  # print(len(one_x),len(X_test),len(one_y),len(y_test))
  return one_x,X_test

# %%
#This is the solution for B..one data per class for trainig.........
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
accuracy = dict()
for i in range(1,7):
  accuracy[i]=[0]
for iter in range(1,21):
  for i in range(1,7):
    total_train_df,total_test_df,one_six_train_df = data_split(i)
    X_train,y_train,X_test,y_test,one_x,one_y= split_x_y(total_train_df,total_test_df,one_six_train_df)
    one_x,X_test = scaling_data(one_x,X_test)

    classifier = KNeighborsClassifier(n_neighbors=1)
    classifier.fit(one_x, one_y)
    y_pred_one = classifier.predict(X_test)
    res = metrics.accuracy_score(y_test, y_pred_one)
    temp = accuracy[i]
    temp.append(res)
    accuracy[i]=temp
    # print("Accuracy for the value of k = 1 is  ",metrics.accuracy_score(y_test, y_pred_one))

# %%
for i in range(1,7):
  print(accuracy[i])
# Out:
# [0, 0.43125, 0.35625, 0.39375, 0.38125, 0.39375, 0.34375, 0.2625, 0.40625, 0.41875, 0.35, 0.39375, 0.35625, 0.45625, 0.43125, 0.45, 0.44375, 0.425, 0.36875, 0.425, 0.41875]
# [0, 0.4375, 0.4625, 0.48125, 0.40625, 0.46875, 0.4625, 0.45625, 0.5, 0.5, 0.56875, 0.475, 0.525, 0.4125, 0.43125, 0.41875, 0.40625, 0.39375, 0.45625, 0.4125, 0.45625]
# [0, 0.5125, 0.54375, 0.5, 0.49375, 0.45, 0.5125, 0.5375, 0.525, 0.46875, 0.475, 0.50625, 0.5375, 0.5, 0.5, 0.56875, 0.525, 0.45, 0.525, 0.49375, 0.4875]
# [0, 0.525, 0.54375, 0.49375, 0.54375, 0.50625, 0.55, 0.53125, 0.525, 0.5125, 0.53125, 0.5625, 0.60625, 0.5375, 0.6, 0.55, 0.575, 0.5125, 0.54375, 0.55, 0.53125]
# [0, 0.5625, 0.525, 0.50625, 0.6125, 0.625, 0.58125, 0.5625, 0.60625, 0.5375, 0.6, 0.56875, 0.53125, 0.525, 0.575, 0.6, 0.5875, 0.6125, 0.575, 0.575, 0.5625]
# [0, 0.5375, 0.5625, 0.525, 0.5625, 0.5625, 0.61875, 0.5625, 0.6, 0.58125, 0.5875, 0.575, 0.54375, 0.58125, 0.55, 0.575, 0.54375, 0.61875, 0.60625, 0.575, 0.6]

# %% [markdown]
# # **Solution of B:From the accuracy dictionary we can say that the accuracy for k=1 and n=1 then with the test data is = .43125(though it changes with the undefined random state during split the data)**

# %%
# import the math module  
import math
mean_accuracy = {}
for i in range(1,7):
    temp=accuracy[i]
    sum = 0 
    for j in temp:
      sum+=j
    mean_accuracy[i]=sum/20
for key,value in mean_accuracy.items():
  print("The mean accuracy when n = {} is ".format(key),value)
#Standard deviation.........
standard_dev = {}
for i in range(1,7):
  sum = 0
  list_ac = accuracy[i]
  for j in range(1,21):
    mean = mean_accuracy[i]
    temp = (mean-list_ac[j])
    temp*=temp
    sum+=temp
  dev = sum/20
  dev = math.sqrt(dev)
  standard_dev[i]=dev
for key,value in standard_dev.items():
  print("The standard deviation with respect to the num or data n = {} is ".format(key),value)
# Out:
# The mean accuracy when n = 1 is  0.39531250000000007
# The mean accuracy when n = 2 is  0.4565625
# The mean accuracy when n = 3 is  0.505625
# The mean accuracy when n = 4 is  0.5415625
# The mean accuracy when n = 5 is  0.5715625
# The mean accuracy when n = 6 is  0.5734374999999999
# The standard deviation with respect to the num or data n = 1 is  0.04523700607633091
# The standard deviation with respect to the num or data n = 2 is  0.043322689999006306
# The standard deviation with respect to the num or data n = 3 is  0.02990218428476421
# The standard deviation with respect to the num or data n = 4 is  0.027830050642246407
# The standard deviation with respect to the num or data n = 5 is  0.032444363435734105
# The standard deviation with respect to the num or data n = 6 is  0.025835643377899457

# %% [markdown]
# #**Solution of D: We can see the accuracy of 20 iteration along with different num of data...accuracy dictionary has these accuracy information. And the mean accuracy of these different n is: provided in mean_accuracy dictionary**

# %%
average_accuracy = []
stadard_deviation = []
for i in range(1,7):
  average_accuracy.append(mean_accuracy[i])
  stadard_deviation.append(standard_dev[i])

from sklearn import metrics
plt.plot(range(1,7), average_accuracy)
plt.xlabel('Number of Data(n)')
plt.ylabel('Average Accuracy')
plt.title('Accuracy with respect to the use of data')
plt.legend() 
plt.show()


plt.plot(range(1,7), stadard_deviation)
plt.xlabel('Number of Data(n)')
plt.ylabel('Standard Deviation')
plt.title('Standard Deviation with respect to the use of data')
plt.show()

plt.plot(range(1,7), average_accuracy, label = "Average Accuracy Line")
plt.plot(range(1,7), stadard_deviation ,label = "Standard Deviation")
plt.xlabel('Number of Data(n)')
plt.ylabel('Average Accuracy')
plt.title('Accuracy and Standard Deviation with respect to the use of data')
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.
